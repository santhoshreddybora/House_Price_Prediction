# %%
import pandas as pd

# %%
pwd
# Out:
# 'd:\\MachineLearning\\HousePrice\\HPP\\notebook'

# %%
data=pd.read_csv('bengaluru_house_prices.csv')
data.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
data_dict=data.to_dict(orient='records')
data_dict
# Out:
# [{'area_type': 'Super built-up  Area',
#   'availability': '19-Dec',
#   'location': 'Electronic City Phase II',
#   'size': '2 BHK',
#   'society': 'Coomee ',
#   'total_sqft': '1056',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 39.07},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Chikka Tirupathi',
#   'size': '4 Bedroom',
#   'society': 'Theanmp',
#   'total_sqft': '2600',
#   'bath': 5.0,
#   'balcony': 3.0,
#   'price': 120.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Uttarahalli',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '1440',
#   'bath': 2.0,
#   'balcony': 3.0,
#   'price': 62.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Lingadheeranahalli',
#   'size': '3 BHK',
#   'society': 'Soiewre',
#   'total_sqft': '1521',
#   'bath': 3.0,
#   'balcony': 1.0,
#   'price': 95.0},
#  {'area_type': 'Super built-up  Area',
# ...

# %%
##Creating a data base for storing data

Db_name='HousePrice'
Collection_name='House'
Connection_url="mongodb+srv://borasanthosh921:borasanthosh921@cluster0.hocq1pf.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
import pymongo
client_object= pymongo.MongoClient(Connection_url)
data_base=client_object[Db_name]
collection=data_base[Collection_name]
rec=collection.insert_many(data_dict)

# %%
records=collection.find()

# %%
for i,j in enumerate(records):
    print(i,j)
# Out:
# 0 {'_id': ObjectId('66386d7743d88bfe424fe2aa'), 'area_type': 'Super built-up  Area', 'availability': '19-Dec', 'location': 'Electronic City Phase II', 'size': '2 BHK', 'society': 'Coomee ', 'total_sqft': '1056', 'bath': 2.0, 'balcony': 1.0, 'price': 39.07}
# 1 {'_id': ObjectId('66386d7743d88bfe424fe2ab'), 'area_type': 'Plot  Area', 'availability': 'Ready To Move', 'location': 'Chikka Tirupathi', 'size': '4 Bedroom', 'society': 'Theanmp', 'total_sqft': '2600', 'bath': 5.0, 'balcony': 3.0, 'price': 120.0}
# 2 {'_id': ObjectId('66386d7743d88bfe424fe2ac'), 'area_type': 'Built-up  Area', 'availability': 'Ready To Move', 'location': 'Uttarahalli', 'size': '3 BHK', 'society': nan, 'total_sqft': '1440', 'bath': 2.0, 'balcony': 3.0, 'price': 62.0}
# ...

# %%
df=pd.DataFrame(list(collection.find()))
df
# Out:
#                             _id             area_type   availability  \
# 0      66386d7743d88bfe424fe2aa  Super built-up  Area         19-Dec
# 1      66386d7743d88bfe424fe2ab            Plot  Area  Ready To Move
# 2      66386d7743d88bfe424fe2ac        Built-up  Area  Ready To Move
# 3      66386d7743d88bfe424fe2ad  Super built-up  Area  Ready To Move
# 4      66386d7743d88bfe424fe2ae  Super built-up  Area  Ready To Move
# ...                         ...                   ...            ...
# 13315  66386d7743d88bfe425016ad        Built-up  Area  Ready To Move
# 13316  66386d7743d88bfe425016ae  Super built-up  Area  Ready To Move
# 13317  66386d7743d88bfe425016af        Built-up  Area  Ready To Move
# 13318  66386d7743d88bfe425016b0  Super built-up  Area         18-Jun
# 13319  66386d7743d88bfe425016b1  Super built-up  Area  Ready To Move
#
#                        location       size  society total_sqft  bath  balcony  \
# ...

# %%
df=df.drop(columns=['_id'],axis=1)
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...
